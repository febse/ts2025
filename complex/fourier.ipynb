# %% [markdown]
# # The Complex Sine Wave
#
# Our previous approach to calculating the similarity between a time series (signal) and real sine wave
# relied on calculating the value of the sine wave for a discrete grid of time points, corresponding to the sampling times (observation times) of the signal.

# %%
import numpy as np

# %%
# 5 samples per period (assuming period = 1 second)
samples_per_period = 4
t = np.linspace(0.0, 4.0, 4 * samples_per_period, endpoint=False)  # 0 to 4 seconds, inclusive[:-1]  # Exclude the last point to avoid duplication

t
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 ,
#        2.75, 3.  , 3.25, 3.5 , 3.75])
